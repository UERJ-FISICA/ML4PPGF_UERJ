# %% [markdown]
# <a href="https://colab.research.google.com/github/UERJ-FISICA/ML4PPGF_UERJ/blob/master/2026-1/Aula0_Apresenta%C3%A7%C3%A3o_do_curso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning PPGF -- Semestre 2026-1
# Disciplina do Programa de Pós Graduação em Física da UERJ
# * Professores: Andre Sznajder e Helena Malbouisson
# * Horário: Terças-feiras, de 12:30 às 16:00 (T1 - T4, 4 tempos por semana)
#    * 2 tempos de introdução teórica
#    * 2 tempos de *hands-on*
# * Semestre 2026-1:
#    * 18 aulas no total
#       * 1a aula: 10/03/2026
#       * Última aula: 14/07/2026

# %% [markdown]
# ## Ementa
#
# Machine Learning PPGF -- Semestre 2026-1
#
# ```
#     Parte I -- Os fundamentos do Aprendizado de Máquina
# ```
#
#  - Introdução a aprendizado de máquinas e aplicações com Python
#
# - O que é aprendizado de máquina (ML) e por quê usar?
#
# - Sistemas de aprendizado de máquina: supervisionado/não supervisionado.
#
# - Desafios no aprendizado de máquina: qualidade dos dados, overfitting, underfitting
#
# - Redução de dimensionalidade
#
# - Testes e validação de modelos
#
# - Os algoritmos mais comuns de aprendizado de máquina:
#    - Repgressão Linear e Polinomial
#    - Repgressão Logística
#    - *k-Nearest Neighbors*
#    - *Support Vector Machines*
#    - Árvores de decisão
#    - *Random Forests*
#    - Métodos de Ensemble
#
# - Projetos e exercícios de ML usando Scikit Learn
#
# ```
#     Parte II -- Redes Neurais e Redes Profundas
# ```
#
# - Redes neurais em Python usando Keras e TensorFlow
# - O quê são redes neurais (NN)?
# - Tipos de redes neurais : feed forward ou recurrent
# - Paradigmas de aprendizado: supervisionado, não supervisionado ou reforçado
# - Técnicas de aprendizado: Gradient Descent, Backpropagation, Regularização.
# - Arquiteturas de redes neurais profundas (DNN) : CNN,RNN, LSTM, Autoencoders, etc.
#
#
# ```
#     Bibliografia:
# ```
# 1. Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and
# Techniques to Build Intelligent System, Aurélien Géron, 2017
# 2. Statistical data analysis, Glen Cowan, 1998.
# 3. Statistical Methods In Experimental Physics, Frederick James, 2006.

# %% [markdown]
# ## Avaliações
#
# As avaliações serão feitas por meio de dois projetos, relativos às Partes I e Parte Parte II da disciplina

# %% [markdown]
# ## Conhecimentos prévios necessários
#
# Assume-se que os alunos tenham conhecimento de probabilidades e estatística. E que também saibam programar em Python e fazer uso dos pacotes Pandas, Numpy e Matplotlib.

# %% [markdown]
# # Aula 0
#
# <!--BOOK_INFORMATION-->
# <img align="left" width= 150 style="padding-right:10px;" src="https://covers.oreillystatic.com/images/0636920052289/lrg.jpg">
#
# *Essa aula é inteiramente baseada no **capítulo 1, The Machine Learning Landscape** do livro [Hands-On Machine Learning with Scikit-Learn & TensorFlow](http://shop.oreilly.com/product/0636920052289.do) by Aurélien Geron; os notebooks do livro estão disponíveis [no GitHub](https://github.com/ageron/handson-ml).*

# %% [markdown]
# Nessa primeira aula vamos abordar o que é Aprendizado de Máquina e quando fazer uso.
#
# Falaremos principalmente de forma conceitual, mas é importante ter clareza sobre os conceitos, para que possamos avançar com segurança sobre os detalhes de cada um dos tópicos.
#
# Os slides referência desse notebook se encontram [nesse link](https://docs.google.com/presentation/d/1CqO2RBp57ryK9C1djMxehY7pGywwxW_xxSuJEPOv92A/edit?usp=sharing).
